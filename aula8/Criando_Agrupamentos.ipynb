# %% [markdown]
# # Relatório de Análise VII

# %% [markdown]
# ## Criando Agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('../dados/aluguel_residencial.csv', sep=';')
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# 2    800.0       390.0  20.0     53.33   Apartamento
# 3    800.0       230.0   0.0     16.67   Apartamento
# 4   1300.0       301.0  17.0     26.00   Apartamento
# 5  22000.0         0.0   0.0     29.33   Apartamento
# 6   1000.0         0.0   0.0     15.38   Apartamento
# 7   1500.0       642.0  74.0     21.43   Apartamento
# 8   1500.0       455.0  14.0     16.67   Apartamento
# 9   2000.0       561.0  50.0     50.00   Apartamento

# %% [markdown]
# #### https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats

# %%
dados['Valor'].mean()
# Out:
# 5046.172821405663

# %%
dados['Bairro'].unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
#        'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
#        'Tijuca', 'Olaria', 'Ipanema', 'Campo Grande', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'São Conrado', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
#        'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
#        'Flamengo', 'Piedade', 'Lagoa', 'Catete', 'Jardim Carioca',
#        'Benfica', 'Glória', 'Praça Seca', 'Vila Isabel', 'Engenho Novo',
#        'Engenho de Dentro', 'Pilares', 'Água Santa', 'São Cristóvão',
#        'Ilha do Governador', 'Jardim Sulacap', 'Oswaldo Cruz',
#        'Vila da Penha', 'Anil', 'Vargem Grande', 'Tanque', 'Vaz Lobo',
#        'Madureira', 'São Francisco Xavier', 'Pechincha', 'Leme', 'Irajá',
#        'Quintino Bocaiúva', 'Urca', 'Penha', 'Gardênia Azul',
#        'Rio Comprido', 'Andaraí', 'Santa Teresa', 'Inhaúma',
#        'Marechal Hermes', 'Curicica', 'Santíssimo', 'Moneró', 'Camorim',
#        'Cascadura', 'Praia da Bandeira', 'Saúde', 'Joá', 'Realengo',
#        'Fátima', 'Inhoaíba', 'Rocha', 'Jardim Guanabara', 'Jabour',
#        'Braz de Pina', 'Praça da Bandeira', 'Vila Kosmos', 'Vista Alegre',
#        'Encantado', 'Campinho', 'Guaratiba', 'Riachuelo', 'Bangu', 'Lapa',
#        'Catumbi', 'Penha Circular', 'Abolição', 'Tomás Coelho', 'Colégio',
#        'Pavuna', 'Santa Cruz', 'Alto da Boa Vista', 'Cidade Nova',
#        'Bento Ribeiro', 'Estácio', 'Jardim América', 'Cordovil', 'Caju',
#        'Pedra de Guaratiba', 'Padre Miguel', 'Paciência', 'Del Castilho',
#        'Arpoador', 'Sampaio', 'Anchieta', 'Icaraí', 'Senador Vasconcelos',
#        'Rocha Miranda', 'Gamboa', 'Maria da Graça', 'Barra de Guaratiba',
#        'Vicente de Carvalho', 'Paquetá', 'Largo do Machado',
#        'Parada de Lucas', 'Freguesia (Ilha do Governador)', 'Portuguesa',
#        'Guadalupe', 'Parque Anchieta', 'Turiaçu', 'Pitangueiras',
#        'Vila Militar', 'Vidigal', 'Senador Camará', 'Usina',
#        'Vigário Geral', 'Cosmos', 'Jacaré', 'Cocotá', 'Honório Gurgel',
#        'Engenho da Rainha', 'Cachamorra', 'Zumbi', 'Tauá', 'Santo Cristo',
#        'Ribeira', 'Magalhães Bastos', 'Cacuia', 'Bancários', 'Cavalcanti',
#        'Rio da Prata', 'Cidade Jardim', 'Coelho Neto'], dtype=object)

# %%
bairros = ['Copacabana', 'Jardim Botânico', 'Centro', 'Barra da Tijuca', 'Grajaú']

# %%
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]

# %%
dados.head(10)
# Out:
#                   Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete       Copacabana        1      0       0    40
# 1                 Casa  Jardim Botânico        2      0       1   100
# 2          Apartamento           Centro        1      0       0    15
# 5   Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7          Apartamento           Grajaú        2      1       0    70
# 9          Apartamento       Copacabana        1      0       1    40
# 10           Quitinete       Copacabana        1      0       0    27
# 11         Apartamento       Copacabana        4      3       1   243
# 14         Apartamento  Barra da Tijuca        2      1       1    67
# 16  Casa de Condomínio  Barra da Tijuca        4      3       2   466
#
#       Valor  Condominio   IPTU  Valor m2 Tipo Agregado
# 0    1700.0       500.0   60.0     42.50   Apartamento
# 1    7000.0         0.0    0.0     70.00          Casa
# 2     800.0       390.0   20.0     53.33   Apartamento
# 5   22000.0         0.0    0.0     29.33   Apartamento
# 7    1500.0       642.0   74.0     21.43   Apartamento
# 9    2000.0       561.0   50.0     50.00   Apartamento
# 10   1800.0       501.0    0.0     66.67   Apartamento
# 11  13000.0      2000.0  803.0     53.50   Apartamento
# 14   1700.0       589.0  147.0     25.37   Apartamento
# 16   7500.0      2695.0    0.0     16.09   Apartamento

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0         Copacabana
# 1    Jardim Botânico
# 2             Centro
# 5    Barra da Tijuca
# 7             Grajaú
# Name: Bairro, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Centro': [2, 38, 65, 71, 146, 181, 191, 312, 427, 585, 665, 826, 870, 939, 944, 954, 1016, 1111, 1115, 1136, 1321, 1385, 1483, 1496, 1613, 1633, 1691, 1697, 1733, 1737, 1845, 1891, 1901, 2006, 2085, 2098, 2156, 2167, 2191, 2236, 2239, 2258, 2326, 2445, 2466, 2605, 2614, 2971, 3076, 3082, 3090, 3240, 3278, 3329, 3330, 3343, 3481, 3530, 3576, 3690, 3772, 3865, 3909, 3929, 3936, 4025, 4027, 4042, 4177, 4327, 4371, 4445, 4464, 4503, 4719, 4788, 4838, 4859, 4877, 4915, 4933, 4934, 5016, 5031, 5049, 5077, 5102, 5112, 5157, 5161, 5172, 5287, 5313, 5337, 5381, 5448, 5629, 5693, 5728, 5799, ...], 'Copacabana': [0, 9, 10, 11, 24, 25, 28, 31, 86, 91, 104, 109, 125, 129, 140, 142, 143, 151, 162, 174, 184, 192, 194, 206, 223, 249, 263, 275, 278, 281, 289, 290, 301, 307, 319, 327, 329, 348, 359, 365, 371, 372, 388, 396, 404, 425, 426, 437, 458, 460, 485, 486, 487, 497, 530, 532, 534, 557, 564, 573, 574, 583, 606, 610, 612, 615, 633, 650, 659, 666, 667, 678, 687, 689, 694, 701, 713, 730, 736, 739, 772, 808, 824, 836, 872, 881, 894, 898, 907, 912, 917, 919, 921, 922, 929, 952, 963, 964, 980, 989, ...], 'Grajaú': [7, 238, 317, 408, 410, 471, 570, 971, 1337, 1450, 1564, 1621, 1978, 2521, 2564, 2746, 2756, 2794, 2850, 3010, 3404, 3496, 3715, 3986, 4202, 4559, 4601, 4668, 4862, 5080, 5095, 5275, 5304, 5320, 5325, 5525, 5540, 6033, 6646, 6948, 7301, 7566, 7822, 7913, 7934, 8038, 8439, 8559, 8564, 9019, 9042, 9049, 9141, 9231, 9763, 10119, 10247, 10262, 10396, 10558, 10567, 10616, 11062, 11248, 11276, 11303, 11304, 11316, 11625, 11702, 11813, 12069, 12071, 12079, 12097, 12290, 12504, 12531, 12542, 12549, 12574, 12605, 12821, 12871, 13667, 13831, 13988, 14020, 14254, 14336, 14362, 14509, 14603, 14644, 14736, 14869, 14981, 15089, 15101, 15441, ...], 'Jardim Botânico': [1, 55, 310, 323, 351, 445, 446, 492, 495, 571, 643, 675, 806, 937, 982, 1187, 1211, 1374, 1484, 1795, 1884, 2053, 2061, 2102, 2249, 2523, 2526, 2692, 2712, 2731, 2813, 2817, 3214, 3370, 3473, 3486, 3583, 3735, 3764, 3782, 3961, 4059, 4062, 4121, 4237, 4472, 4585, 4702, 4709, 4789, 4866, 4889, 4914, 5024, 5084, 5116, 5168, 5198, 5232, 5262, 5301, 5341, 5382, 5399, 5418, 5598, 5665, 5702, 5809, 5836, 5886, 6276, 6326, 6399, 6484, 6512, 6643, 6736, 6740, 6741, 6745, 6773, 6789, 6813, 6908, 6921, 6971, 7001, 7055, 7113, 7357, 7362, 7469, 7528, 7734, 7878, 7916, 8050, 8171, 8201, ...]}

# %%
for bairro, dados in grupo_bairro:
    print(bairro)
# Out:
# Barra da Tijuca
# Centro
# Copacabana
# Grajaú
# Jardim Botânico

# %%
for bairro, dados in grupo_bairro:
    print(dados)
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 5      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 14            Apartamento  Barra da Tijuca        2      1       1    67
# 16     Casa de Condomínio  Barra da Tijuca        4      3       2   466
# 21            Apartamento  Barra da Tijuca        3      3       1   175
# 30            Apartamento  Barra da Tijuca        3      1       2    70
# ...                   ...              ...      ...    ...     ...   ...
# 21801  Casa de Condomínio  Barra da Tijuca        3      5       3  1000
# 21811         Apartamento  Barra da Tijuca        2      1       1    85
# 21812         Apartamento  Barra da Tijuca        3      2       0    98
# 21813         Apartamento  Barra da Tijuca        3      2       2   140
# 21820  Casa de Condomínio  Barra da Tijuca        5      3       4   450
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 5      22000.0         0.0     0.0     29.33   Apartamento
# 14      1700.0       589.0   147.0     25.37   Apartamento
# 16      7500.0      2695.0     0.0     16.09   Apartamento
# 21      4200.0      1500.0   500.0     24.00   Apartamento
# 30      1800.0      1095.0   140.0     25.71   Apartamento
# ...        ...         ...     ...       ...           ...
# 21801  20000.0      3000.0     0.0     20.00   Apartamento
# 21811   2250.0      1561.0   197.0     26.47   Apartamento
# 21812   2300.0       887.0   177.0     23.47   Apartamento
# 21813   5500.0      1900.0   700.0     39.29   Apartamento
# 21820  15000.0      1711.0  2332.0     33.33   Apartamento
#
# [3863 rows x 11 columns]
#               Tipo  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 2      Apartamento  Centro        1      0       0    15   800.0       390.0
# 38     Apartamento  Centro        1      0       0    27   750.0       371.0
# 65     Apartamento  Centro        1      1       0    37  1100.0       540.0
# 71       Quitinete  Centro        0      0       0    30   800.0       505.0
# 146      Quitinete  Centro        0      0       0    28   700.0       400.0
# ...            ...     ...      ...    ...     ...   ...     ...         ...
# 21545         Casa  Centro        2      0       0   207  4000.0         0.0
# 21625  Apartamento  Centro        2      0       0    70  2500.0       660.0
# 21748    Quitinete  Centro        1      0       0    24  1100.0       323.0
# 21804         Casa  Centro        5      0       1   160  5000.0         0.0
# 21822    Quitinete  Centro        0      0       0    27   800.0       350.0
#
#         IPTU  Valor m2 Tipo Agregado
# 2       20.0     53.33   Apartamento
# 38      19.0     27.78   Apartamento
# 65     900.0     29.73   Apartamento
# 71       0.0     26.67   Apartamento
# 146     16.0     25.00   Apartamento
# ...      ...       ...           ...
# 21545    0.0     19.32          Casa
# 21625   85.0     35.71   Apartamento
# 21748    0.0     45.83   Apartamento
# 21804   80.0     31.25          Casa
# 21822   25.0     29.63   Apartamento
#
# [343 rows x 11 columns]
#               Tipo      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0        Quitinete  Copacabana        1      0       0    40   1700.0
# 9      Apartamento  Copacabana        1      0       1    40   2000.0
# 10       Quitinete  Copacabana        1      0       0    27   1800.0
# 11     Apartamento  Copacabana        4      3       1   243  13000.0
# 24     Apartamento  Copacabana        3      1       2   378  10000.0
# ...            ...         ...      ...    ...     ...   ...      ...
# 21783  Apartamento  Copacabana        1      0       0    60   2400.0
# 21795  Apartamento  Copacabana        2      0       0    67   2450.0
# 21809  Apartamento  Copacabana        2      0       1    70   4100.0
# 21810  Apartamento  Copacabana        1      0       0    50   1950.0
# 21815    Quitinete  Copacabana        1      0       0    22   1500.0
#
#        Condominio   IPTU  Valor m2 Tipo Agregado
# 0           500.0   60.0     42.50   Apartamento
# 9           561.0   50.0     50.00   Apartamento
# 10          501.0    0.0     66.67   Apartamento
# 11         2000.0  803.0     53.50   Apartamento
# 24         2150.0  700.0     26.46   Apartamento
# ...           ...    ...       ...           ...
# 21783       530.0   78.0     40.00   Apartamento
# 21795       679.0   80.0     36.57   Apartamento
# 21809       700.0   90.0     58.57   Apartamento
# 21810       450.0   70.0     39.00   Apartamento
# 21815       286.0  200.0     68.18   Apartamento
#
# [2644 rows x 11 columns]
#               Tipo  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 7      Apartamento  Grajaú        2      1       0    70  1500.0       642.0
# 238           Casa  Grajaú        5      4       2   450  7000.0         0.0
# 317    Apartamento  Grajaú        2      0       0    65  1400.0       415.0
# 408    Apartamento  Grajaú        3      2       1    90  2950.0       700.0
# 410    Apartamento  Grajaú        1      0       0    30   800.0       283.0
# ...            ...     ...      ...    ...     ...   ...     ...         ...
# 21229  Apartamento  Grajaú        2      0       0    47  1150.0       448.0
# 21409  Apartamento  Grajaú        3      2       1    90  1700.0       900.0
# 21484  Apartamento  Grajaú        2      0       0    66  1300.0       392.0
# 21558  Apartamento  Grajaú        1      1       0    56  1100.0       580.0
# 21570  Apartamento  Grajaú        1      0       1    37  1000.0       200.0
#
#         IPTU  Valor m2 Tipo Agregado
# 7       74.0     21.43   Apartamento
# 238    500.0     15.56          Casa
# 317     21.0     21.54   Apartamento
# 408    100.0     32.78   Apartamento
# 410    187.0     26.67   Apartamento
# ...      ...       ...           ...
# 21229    0.0     24.47   Apartamento
# 21409   87.0     18.89   Apartamento
# 21484   25.0     19.70   Apartamento
# 21558  420.0     19.64   Apartamento
# 21570    0.0     27.03   Apartamento
#
# [145 rows x 11 columns]
#               Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 1             Casa  Jardim Botânico        2      0       1   100   7000.0
# 55     Apartamento  Jardim Botânico        2      2       0    95   4000.0
# 310           Casa  Jardim Botânico        2      4       1   107   9500.0
# 323    Apartamento  Jardim Botânico        3      1       2   170   6000.0
# 351    Apartamento  Jardim Botânico        3      1       1   130   6400.0
# ...            ...              ...      ...    ...     ...   ...      ...
# 21394  Apartamento  Jardim Botânico        1      1       1    95   2600.0
# 21448         Casa  Jardim Botânico        7      6       4   845  35000.0
# 21546  Apartamento  Jardim Botânico        2      1       1    79   3300.0
# 21659  Apartamento  Jardim Botânico        3      0       1   360  17000.0
# 21798  Apartamento  Jardim Botânico        3      1       2   145   5000.0
#
#        Condominio    IPTU  Valor m2 Tipo Agregado
# 1             0.0     0.0     70.00          Casa
# 55         1170.0     0.0     42.11   Apartamento
# 310           0.0  1091.0     88.79          Casa
# 323         860.0   540.0     35.29   Apartamento
# 351        1500.0     0.0     49.23   Apartamento
# ...           ...     ...       ...           ...
# 21394      1007.0   209.0     27.37   Apartamento
# 21448         0.0     0.0     41.42          Casa
# 21546       965.0   210.0     41.77   Apartamento
# 21659      1700.0  1200.0     47.22   Apartamento
# 21798      1296.0   317.0     34.48   Apartamento
#
# [263 rows x 11 columns]

# %%
for bairro, data in grupo_bairro:
    print(f'{bairro}: {dados.Valor.mean()}')
# Out:
# Barra da Tijuca: 8722.357414448668
# Centro: 8722.357414448668
# Copacabana: 8722.357414448668
# Grajaú: 8722.357414448668
# Jardim Botânico: 8722.357414448668

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                    Valor  Condominio
# Bairro
# Barra da Tijuca  7069.55     3591.01
# Centro           1254.75      422.57
# Copacabana       4126.68     1148.68
# Grajaú           2038.62      575.02
# Jardim Botânico  8722.36     1059.24

# %% [markdown]
# ## Atividades

# %%
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# ## Estatísticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                   count     mean       std     min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  3863.0  7069.55  11874.15   800.0  2500.0  4500.0   8500.0
# Centro            343.0  1254.75    884.67   400.0   800.0  1000.0   1400.0
# Copacabana       2644.0  4126.68   3611.41   100.0  2000.0  3000.0   4800.0
# Grajaú            145.0  2038.62   4901.99   650.0  1250.0  1500.0   1700.0
# Jardim Botânico   263.0  8722.36   9332.73  1550.0  3150.0  4000.0  10000.0
#
#                       max
# Bairro
# Barra da Tijuca  600000.0
# Centro            12000.0
# Copacabana        35000.0
# Grajaú            60000.0
# Jardim Botânico   50000.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns={'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                  Mínimo    Máximo
# Bairro
# Barra da Tijuca   800.0  600000.0
# Centro            400.0   12000.0
# Copacabana        100.0   35000.0
# Grajaú            650.0   60000.0
# Jardim Botânico  1550.0   50000.0

# %% [markdown]
# #### https://matplotlib.org/3.3.3/contents.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(20,10))
font = {'family' : 'monospace',
        'size'   : 22}
plt.rc('font', **font)

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color = 'green')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel for Bairro', {'fontsize': 24})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel for Bairro')

# %% [markdown]
# ## Atividades

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto')
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão', 
    'min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes)
# Out:
#             Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Batata   3.960000       0.256320    3.69     4.2
# Cebola   2.060000       0.409512    1.69     2.5
# Tomate   3.426667       0.518684    2.99     4.0

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão', 
    'min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Batata    3.96           0.26    3.69     4.2
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
